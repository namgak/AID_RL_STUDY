# %% [markdown]
# # 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import glob
import re

import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
from tqdm import tqdm

# %% [markdown]
# # Fixed RandomSeed & Setting Hyperparameter _ 필요한가 고민

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
LOOKBACK, PREDICT, BATCH_SIZE, EPOCHS = 28, 7, 16, 50
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # train 불러오기

# %%
train = pd.read_csv('/content/drive/MyDrive/lgaimers7기/data/train/train.csv')

# %% [markdown]
# # Define Model_ 고민

# %%
class MultiOutputLSTM(nn.Module):
    def __init__(self, input_dim=1, hidden_dim=64, num_layers=2, output_dim=7):
        super(MultiOutputLSTM, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        return self.fc(out[:, -1, :])  # (B, output_dim)

# %% [markdown]
# # Feature Engineeering

# %% [markdown]
# [원시 데이터]
#
#   ↓
#
# [피처 만들기]
#   - 날짜 특징 (요일, 월, 주차, 주말 여부 등)
#   - 시계열 특징 (최근 7일 평균, 14일 평균, 이전 매출량 등)
#   - 업장·메뉴 ID 인코딩
#   - 시즌/성수기 플래그
#
#   ↓
#
# [모델 학습]
#
#   - Horizon=1~7 각각 별도 회귀 모델 (LightGBM)
#   - 업장 가중치 적용 (담하, 미라시아 비중↑)
#
#   ↓
#
# [예측]
#   - 예측 결과 7일치 병합
#
#   ↓
#
# [제출 포맷 변환]

# %% [markdown]
# # 한번에 돌아가는 코드

# %% [markdown]
# 1 데이터 로드 (train, test)
#
# 2 전처리 & 피처 생성
#
# - 날짜 기반 특징
#
# - Lag & Rolling
#
# - 카테고리 인코딩
#
# 3 LightGBM 학습
#
# - day+1 ~ day+7 각각 별도 모델
#
# - 업장 가중치 적용
#
# 4 예측
#
# 5 제출 포맷 변환
#
#
# 그럼 이번엔 제가 아까 준 LightGBM 전역 모델 코드에다가
#
# 공휴일 / 성수기 피처
#
# Seasonal Naïve + 이동평균 앙상블
#
# Optuna를 이용한 하이퍼파라미터 튜닝
#
# 까지 풀패키지로 한 번에 넣어서 드릴게요.
# 이렇게 하면 LSTM 베이스라인보다 리더보드에서 안정적으로 점수 향상을 기대할 수 있습니다.

# %% [markdown]
# 시드 고정안 하고 그냥 돌림

# %%
# !pip  install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 31.5 MB/s eta 0:00:00
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 24.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.4 colorlog-6.9.0 optuna-4.4.0

# %%
import os
import glob
import re
import pandas as pd
import numpy as np
import lightgbm as lgb
import holidays
import optuna
from tqdm import tqdm

# -----------------------
# 1. 데이터 로드
# -----------------------
train = pd.read_csv('/content/drive/MyDrive/lgaimers7기/data/train/train.csv')
sample_submission = pd.read_csv('/content/drive/MyDrive/lgaimers7기/data/sample_submission.csv')

test_files = sorted(glob.glob('/content/drive/MyDrive/lgaimers7기/data/test/TEST_*.csv'))
test_list = []
for path in test_files:
    df = pd.read_csv(path)
    df['test_prefix'] = re.search(r'(TEST_\d+)', os.path.basename(path)).group(1)
    test_list.append(df)
test_all = pd.concat(test_list, ignore_index=True)


if '영업장명' not in train.columns:
    train[['영업장명','메뉴명']] = train['영업장명_메뉴명'].str.split('_', n=1, expand=True)

if '영업장명' not in test_all.columns:
    test_all[['영업장명','메뉴명']] = test_all['영업장명_메뉴명'].str.split('_', n=1, expand=True)





# -----------------------
# 2. 피처 생성 함수
# -----------------------
def create_features(df):
    df['영업일자'] = pd.to_datetime(df['영업일자'])
    df['year'] = df['영업일자'].dt.year
    df['month'] = df['영업일자'].dt.month
    df['day'] = df['영업일자'].dt.day
    df['dayofweek'] = df['영업일자'].dt.dayofweek
    df['weekofyear'] = df['영업일자'].dt.isocalendar().week.astype(int)
    df['is_weekend'] = (df['dayofweek'] >= 5).astype(int)

    # 공휴일 여부
    kr_holidays = holidays.KR(years=df['year'].unique())
    df['is_holiday'] = df['영업일자'].isin(kr_holidays).astype(int)

    # 성수기 (7~8월, 12~1월)
    df['is_peak'] = df['month'].isin([7,8,12,1]).astype(int)
    return df

train = create_features(train)

# Lag & Rolling
def add_lag_features(df, group_cols, target_col, lags, roll_windows):
    df = df.sort_values(['영업장명', '메뉴명', '영업일자'])
    for lag in lags:
        df[f'lag_{lag}'] = df.groupby(group_cols)[target_col].shift(lag)
    for w in roll_windows:
        df[f'roll_mean_{w}'] = df.groupby(group_cols)[target_col].shift(1).rolling(w).mean()
        df[f'roll_std_{w}'] = df.groupby(group_cols)[target_col].shift(1).rolling(w).std()
    return df

train = add_lag_features(train, ['영업장명', '메뉴명'], '매출수량', lags=[1,2,3,7,14], roll_windows=[7,14])


# 문자열 -> category 변환
cat_cols = ['영업장명', '메뉴명', '영업장명_메뉴명']
for col in cat_cols:
    if col in train.columns:
        train[col] = train[col].astype('category')
    if col in test_all.columns:
        test_all[col] = test_all[col].astype('category')


# 업장 가중치
store_weights = train['영업장명'].map(lambda x: 3.0 if x in ['담하','미라시아'] else 1.0)

# -----------------------
# 3. Optuna 튜닝 (Horizon=1만)
# -----------------------
PRED_DAYS = 7
features = [col for col in train.columns if col not in ['영업일자','매출수량'] + [f'y_{i}' for i in range(1,PRED_DAYS+1)]]

train[f'y_1'] = train.groupby(['영업장명','메뉴명'])['매출수량'].shift(-1)
df_train = train.dropna(subset=['y_1'])
X_train = df_train[features]
y_train = df_train['y_1']

def objective(trial):
    params = {
        'objective': 'regression',
        'metric': 'mae',
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'num_leaves': trial.suggest_int('num_leaves', 15, 63),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.7, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.7, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'lambda_l1': trial.suggest_float('lambda_l1', 0, 5.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 0, 5.0),
        'seed': 42
    }
    lgb_train = lgb.Dataset(X_train, y_train, weight=store_weights.loc[df_train.index])
    model = lgb.train(params, lgb_train, num_boost_round=300)
    preds = model.predict(X_train)
    return np.mean(np.abs(y_train - preds))

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)
best_params = study.best_params
best_params.update({'objective':'regression','metric':'mae','seed':42})

# -----------------------
# 4. Multi-Horizon 모델 학습
# -----------------------
models = {}
for day_ahead in range(1, PRED_DAYS+1):
    train[f'y_{day_ahead}'] = train.groupby(['영업장명','메뉴명'])['매출수량'].shift(-day_ahead)
    df_train = train.dropna(subset=[f'y_{day_ahead}'])
    X = df_train[features]
    y = df_train[f'y_{day_ahead}']
    lgb_train = lgb.Dataset(X, y, weight=store_weights.loc[df_train.index])
    model = lgb.train(best_params, lgb_train, num_boost_round=500)
    models[day_ahead] = model

# -----------------------
# 5. 테스트 데이터 준비
# -----------------------
test_all = create_features(test_all)
for col in ['영업장명', '메뉴명']:
    test_all[col] = test_all[col].astype('category')

full_data = pd.concat([train, test_all], sort=False)
full_data = add_lag_features(full_data, ['영업장명', '메뉴명'], '매출수량', lags=[1,2,3,7,14], roll_windows=[7,14])

# -----------------------
# 6. 예측 + 앙상블
# -----------------------
pred_results = []
for test_prefix, group in full_data[full_data['test_prefix'].notnull()].groupby('test_prefix'):
    group = group.sort_values('영업일자')
    for day_ahead in range(1, PRED_DAYS+1):
        X_test = group[features]
        pred_lgb = models[day_ahead].predict(X_test)

        # Seasonal Naive: lag_7
        pred_sn = group['lag_7'].values

        # Moving Average(7일)
        pred_ma = group['roll_mean_7'].values

        # 앙상블
        preds = 0.6*pred_lgb + 0.2*pred_sn + 0.2*pred_ma
        group[f'pred_{day_ahead}'] = np.clip(preds, 0, None)
    pred_results.append(group)

pred_df = pd.concat(pred_results)

# -----------------------
# 7. 제출 변환 (수정)
# -----------------------
submit_dict = {}
for _, row in pred_df.iterrows():
    # 업장명_메뉴명 문자열로 합치기
    menu_str = f"{row['영업장명']}_{row['메뉴명']}"
    for day_ahead in range(1, PRED_DAYS+1):
        key = (f"{row['test_prefix']}+{day_ahead}일", menu_str)
        submit_dict[key] = row[f'pred_{day_ahead}']

final_df = sample_submission.copy()
for idx in final_df.index:
    date = final_df.loc[idx, '영업일자']
    for col in final_df.columns[1:]:
        final_df.loc[idx, col] = submit_dict.get((date, col), 0)

final_df.to_csv('lgbm_optuna_ensemble_submission.csv', index=False, encoding='utf-8-sig')
print("제출 파일 저장 완료: lgbm_optuna_ensemble_submission.csv")
# Out:
# /tmp/ipython-input-757050905.py:50: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df['is_holiday'] = df['영업일자'].isin(kr_holidays).astype(int)
# /tmp/ipython-input-757050905.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train[f'y_1'] = train.groupby(['영업장명','메뉴명'])['매출수량'].shift(-1)
# [I 2025-08-13 21:57:46,965] A new study created in memory with name: no-name-fb40d1ce-fc7c-4c1a-a55e-ee2ed95d252f
# [I 2025-08-13 21:57:51,399] Trial 0 finished with value: 6.190964198917949 and parameters: {'learning_rate': 0.030338253714452673, 'num_leaves': 15, 'feature_fraction': 0.7247908519235143, 'bagging_fraction': 0.789251260591224, 'bagging_freq': 5, 'lambda_l1': 1.3452948222068506, 'lambda_l2': 1.6966050671566686}. Best is trial 0 with value: 6.190964198917949.
# [I 2025-08-13 21:57:55,611] Trial 1 finished with value: 6.519684529033572 and parameters: {'learning_rate': 0.012170522170884698, 'num_leaves': 29, 'feature_fraction': 0.704850086004154, 'bagging_fraction': 0.7203615788228457, 'bagging_freq': 6, 'lambda_l1': 3.019445759993782, 'lambda_l2': 2.749988037704243}. Best is trial 0 with value: 6.190964198917949.
# [I 2025-08-13 21:58:03,229] Trial 2 finished with value: 4.558303074847539 and parameters: {'learning_rate': 0.037041111011967345, 'num_leaves': 58, 'feature_fraction': 0.7960921377420777, 'bagging_fraction': 0.9957246683169376, 'bagging_freq': 2, 'lambda_l1': 2.8497838710812804, 'lambda_l2': 0.7782945943022423}. Best is trial 2 with value: 4.558303074847539.
# [I 2025-08-13 21:58:08,530] Trial 3 finished with value: 4.629716167039579 and parameters: {'learning_rate': 0.07160385907206467, 'num_leaves': 44, 'feature_fraction': 0.9958307830499934, 'bagging_fraction': 0.7026959762195591, 'bagging_freq': 6, 'lambda_l1': 0.6348827400826224, 'lambda_l2': 4.459353189714465}. Best is trial 2 with value: 4.558303074847539.
# [I 2025-08-13 21:58:14,041] Trial 4 finished with value: 4.617185955656808 and parameters: {'learning_rate': 0.08234412812903526, 'num_leaves': 38, 'feature_fraction': 0.7188373468365739, 'bagging_fraction': 0.7226112351214469, 'bagging_freq': 2, 'lambda_l1': 0.13570302077744067, 'lambda_l2': 4.8465166956893055}. Best is trial 2 with value: 4.558303074847539.
# [I 2025-08-13 21:58:18,914] Trial 5 finished with value: 4.9683085940963805 and parameters: {'learning_rate': 0.09171114248746506, 'num_leaves': 21, 'feature_fraction': 0.9542804684389752, 'bagging_fraction': 0.8313101650272292, 'bagging_freq': 2, 'lambda_l1': 2.0634762014236676, 'lambda_l2': 4.041345345586656}. Best is trial 2 with value: 4.558303074847539.
# [I 2025-08-13 21:58:24,672] Trial 6 finished with value: 4.449602333810409 and parameters: {'learning_rate': 0.05358399056635299, 'num_leaves': 60, 'feature_fraction': 0.7444633197265872, 'bagging_fraction': 0.7819513261585486, 'bagging_freq': 7, 'lambda_l1': 4.5700270611175675, 'lambda_l2': 1.3758678459128744}. Best is trial 6 with value: 4.449602333810409.
# [I 2025-08-13 21:58:30,389] Trial 7 finished with value: 4.485425245709221 and parameters: {'learning_rate': 0.08867199587581606, 'num_leaves': 38, 'feature_fraction': 0.8704623555552705, 'bagging_fraction': 0.7446420284172541, 'bagging_freq': 7, 'lambda_l1': 1.0691834004426455, 'lambda_l2': 2.1824427005445073}. Best is trial 6 with value: 4.449602333810409.
# [I 2025-08-13 21:58:35,719] Trial 8 finished with value: 4.154820778021487 and parameters: {'learning_rate': 0.09192024050700469, 'num_leaves': 50, 'feature_fraction': 0.9159809154104165, 'bagging_fraction': 0.8035516456634524, 'bagging_freq': 4, 'lambda_l1': 1.527446701058649, 'lambda_l2': 2.3962578787928637}. Best is trial 8 with value: 4.154820778021487.
# [I 2025-08-13 21:58:43,314] Trial 9 finished with value: 4.928174073138571 and parameters: {'learning_rate': 0.029881705216717624, 'num_leaves': 50, 'feature_fraction': 0.8947914586445455, 'bagging_fraction': 0.9945083995673282, 'bagging_freq': 2, 'lambda_l1': 3.3250843233417937, 'lambda_l2': 2.239393847055224}. Best is trial 8 with value: 4.154820778021487.
# [I 2025-08-13 21:58:49,002] Trial 10 finished with value: 4.239812016207902 and parameters: {'learning_rate': 0.06721419030792504, 'num_leaves': 53, 'feature_fraction': 0.9305864587276999, 'bagging_fraction': 0.9116977040697316, 'bagging_freq': 4, 'lambda_l1': 1.9212729408647935, 'lambda_l2': 3.179737794033935}. Best is trial 8 with value: 4.154820778021487.
# [I 2025-08-13 21:58:55,715] Trial 11 finished with value: 4.269074970271856 and parameters: {'learning_rate': 0.06661473550442112, 'num_leaves': 52, 'feature_fraction': 0.9179083985387553, 'bagging_fraction': 0.9063182723326255, 'bagging_freq': 4, 'lambda_l1': 1.7984312306461505, 'lambda_l2': 3.3455718628517075}. Best is trial 8 with value: 4.154820778021487.
# [I 2025-08-13 21:59:01,349] Trial 12 finished with value: 4.431647027861963 and parameters: {'learning_rate': 0.05974551873695316, 'num_leaves': 50, 'feature_fraction': 0.82430844366439, 'bagging_fraction': 0.9026907872585238, 'bagging_freq': 4, 'lambda_l1': 2.2095509634376143, 'lambda_l2': 3.5231853253558234}. Best is trial 8 with value: 4.154820778021487.
# [I 2025-08-13 21:59:07,895] Trial 13 finished with value: 3.6998189944811974 and parameters: {'learning_rate': 0.09983033832111163, 'num_leaves': 63, 'feature_fraction': 0.943111447500497, 'bagging_fraction': 0.8912392181497713, 'bagging_freq': 3, 'lambda_l1': 3.6703080221067896, 'lambda_l2': 2.911336220059693}. Best is trial 13 with value: 3.6998189944811974.
# [I 2025-08-13 21:59:14,371] Trial 14 finished with value: 3.723835836572319 and parameters: {'learning_rate': 0.0989070250473455, 'num_leaves': 63, 'feature_fraction': 0.9798761055604488, 'bagging_fraction': 0.8415068733053785, 'bagging_freq': 3, 'lambda_l1': 3.9589264028067426, 'lambda_l2': 0.8658694094488828}. Best is trial 13 with value: 3.6998189944811974.
# [I 2025-08-13 21:59:19,204] Trial 15 finished with value: 3.711580779045895 and parameters: {'learning_rate': 0.09709341630838154, 'num_leaves': 63, 'feature_fraction': 0.9838051273863652, 'bagging_fraction': 0.8671124163733562, 'bagging_freq': 1, 'lambda_l1': 4.149685451819405, 'lambda_l2': 0.43702638124022086}. Best is trial 13 with value: 3.6998189944811974.
# [I 2025-08-13 21:59:24,857] Trial 16 finished with value: 3.944555160827356 and parameters: {'learning_rate': 0.07964305275430755, 'num_leaves': 58, 'feature_fraction': 0.9611257457136938, 'bagging_fraction': 0.8766432626519011, 'bagging_freq': 1, 'lambda_l1': 4.984921564510613, 'lambda_l2': 0.21964744703883912}. Best is trial 13 with value: 3.6998189944811974.
# [I 2025-08-13 21:59:29,289] Trial 17 finished with value: 3.590019968315702 and parameters: {'learning_rate': 0.09889512961827125, 'num_leaves': 63, 'feature_fraction': 0.8659804908144226, 'bagging_fraction': 0.9462730158991806, 'bagging_freq': 1, 'lambda_l1': 3.8408550488921227, 'lambda_l2': 0.08067784271105549}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 21:59:34,516] Trial 18 finished with value: 4.507680401222739 and parameters: {'learning_rate': 0.07862226367476154, 'num_leaves': 31, 'feature_fraction': 0.8458582448700351, 'bagging_fraction': 0.9561558561082176, 'bagging_freq': 3, 'lambda_l1': 3.741095534087564, 'lambda_l2': 1.5769524104626307}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 21:59:40,405] Trial 19 finished with value: 4.614331347560667 and parameters: {'learning_rate': 0.05209741358369514, 'num_leaves': 44, 'feature_fraction': 0.8025627946087018, 'bagging_fraction': 0.943528022937819, 'bagging_freq': 3, 'lambda_l1': 3.494918654996642, 'lambda_l2': 2.9086524318059737}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 21:59:44,786] Trial 20 finished with value: 3.8307030404923874 and parameters: {'learning_rate': 0.0993190113684783, 'num_leaves': 55, 'feature_fraction': 0.8732272940421246, 'bagging_fraction': 0.9446772659880822, 'bagging_freq': 1, 'lambda_l1': 2.6509201347853857, 'lambda_l2': 3.931559321011788}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 21:59:50,439] Trial 21 finished with value: 3.657878820082355 and parameters: {'learning_rate': 0.09892659506952425, 'num_leaves': 63, 'feature_fraction': 0.9559846979846214, 'bagging_fraction': 0.869898337102629, 'bagging_freq': 1, 'lambda_l1': 4.134974375682215, 'lambda_l2': 0.15684404547085837}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 21:59:55,104] Trial 22 finished with value: 3.7835150789756575 and parameters: {'learning_rate': 0.08586152095914658, 'num_leaves': 63, 'feature_fraction': 0.947353544628497, 'bagging_fraction': 0.8836937357313738, 'bagging_freq': 1, 'lambda_l1': 4.331055718763404, 'lambda_l2': 0.03991942390223002}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 22:00:02,373] Trial 23 finished with value: 3.9756014023572845 and parameters: {'learning_rate': 0.07816216844211345, 'num_leaves': 56, 'feature_fraction': 0.8816392792137838, 'bagging_fraction': 0.92880339036896, 'bagging_freq': 2, 'lambda_l1': 4.8495558862311325, 'lambda_l2': 0.8620104757905664}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 22:00:07,661] Trial 24 finished with value: 3.9736194935520563 and parameters: {'learning_rate': 0.09229711000019543, 'num_leaves': 46, 'feature_fraction': 0.8996560324817561, 'bagging_fraction': 0.9630472909947808, 'bagging_freq': 3, 'lambda_l1': 3.3289519549108846, 'lambda_l2': 1.1383882427928997}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 22:00:12,300] Trial 25 finished with value: 3.7967007346838324 and parameters: {'learning_rate': 0.09925352954107977, 'num_leaves': 59, 'feature_fraction': 0.9396687323921108, 'bagging_fraction': 0.8595418013879426, 'bagging_freq': 1, 'lambda_l1': 3.822565111305102, 'lambda_l2': 1.9255560156006344}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 22:00:19,292] Trial 26 finished with value: 4.058795874554591 and parameters: {'learning_rate': 0.07360700242815879, 'num_leaves': 60, 'feature_fraction': 0.9705327935280703, 'bagging_fraction': 0.8301536866410937, 'bagging_freq': 5, 'lambda_l1': 4.583635623033082, 'lambda_l2': 0.4763683832602018}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 22:00:24,978] Trial 27 finished with value: 3.9648081934117574 and parameters: {'learning_rate': 0.08566340435954861, 'num_leaves': 55, 'feature_fraction': 0.8496221646463136, 'bagging_fraction': 0.8884521024303592, 'bagging_freq': 2, 'lambda_l1': 3.0405952348618976, 'lambda_l2': 0.49151864543963786}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 22:00:29,841] Trial 28 finished with value: 4.965513128040496 and parameters: {'learning_rate': 0.04722578614762363, 'num_leaves': 32, 'feature_fraction': 0.7809768843957049, 'bagging_fraction': 0.9757939433625532, 'bagging_freq': 1, 'lambda_l1': 3.62724056038563, 'lambda_l2': 2.685418606564677}. Best is trial 17 with value: 3.590019968315702.
# [I 2025-08-13 22:00:33,080] Trial 29 finished with value: 5.130128816173004 and parameters: {'learning_rate': 0.09313015629065352, 'num_leaves': 15, 'feature_fraction': 0.7612506199533768, 'bagging_fraction': 0.9222527150506123, 'bagging_freq': 5, 'lambda_l1': 2.435824828061009, 'lambda_l2': 1.9425274543070692}. Best is trial 17 with value: 3.590019968315702.
# /tmp/ipython-input-757050905.py:124: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train[f'y_{day_ahead}'] = train.groupby(['영업장명','메뉴명'])['매출수량'].shift(-day_ahead)
# /tmp/ipython-input-757050905.py:124: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train[f'y_{day_ahead}'] = train.groupby(['영업장명','메뉴명'])['매출수량'].shift(-day_ahead)
# /tmp/ipython-input-757050905.py:124: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train[f'y_{day_ahead}'] = train.groupby(['영업장명','메뉴명'])['매출수량'].shift(-day_ahead)
# /tmp/ipython-input-757050905.py:124: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train[f'y_{day_ahead}'] = train.groupby(['영업장명','메뉴명'])['매출수량'].shift(-day_ahead)
# /tmp/ipython-input-757050905.py:124: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train[f'y_{day_ahead}'] = train.groupby(['영업장명','메뉴명'])['매출수량'].shift(-day_ahead)
# /tmp/ipython-input-757050905.py:124: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train[f'y_{day_ahead}'] = train.groupby(['영업장명','메뉴명'])['매출수량'].shift(-day_ahead)
# /tmp/ipython-input-757050905.py:124: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train[f'y_{day_ahead}'] = train.groupby(['영업장명','메뉴명'])['매출수량'].shift(-day_ahead)
# /tmp/ipython-input-757050905.py:50: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df['is_holiday'] = df['영업일자'].isin(kr_holidays).astype(int)
# /tmp/ipython-input-757050905.py:62: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[f'lag_{lag}'] = df.groupby(group_cols)[target_col].shift(lag)
# /tmp/ipython-input-757050905.py:64: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[f'roll_mean_{w}'] = df.groupby(group_cols)[target_col].shift(1).rolling(w).mean()
# /tmp/ipython-input-757050905.py:65: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[f'roll_std_{w}'] = df.groupby(group_cols)[target_col].shift(1).rolling(w).std()
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.986553503868544' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.717631112677198' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.661340328030291' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0371554589629413' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.988989808383059' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9631701963206474' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.346989071079928' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.738927217952795' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9125306650000784' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1460316734504012' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6249431525991156' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0962420550583518' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7420155390471248' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.106556286618922' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.48084476276174' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.469996319903005' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.084305109257444' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.560653344372049' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.746830317420073' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4152905233890745' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5206007129125303' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.16364598866011154' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.711810497534068' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7088858838070096' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3858574582381653' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.1154232432056053' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.2802470864650602' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '32.77548667830728' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.913593098899815' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.867603494801397' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.227162767603695' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.231558627606574' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.1152861077400376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0709110057089735' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9595835373413386' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.1972977180248038' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '36.75170887325909' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.048345855552169296' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.197889813945931' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27.720712787856193' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.917876998144525' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8997119706752714' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.1583454694633292' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0557717223745688' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.01881903615602268' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.645754269846839' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4211744848967757' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.784984807059275' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.675155298508564' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6564141342482632' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13.248762871001627' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.41878646882733234' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.519695657546563' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.31705856675844973' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.304478994746124' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9110941063886967' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.6842809618493133' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.594164887412025' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9939125674147073' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6083236602240591' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.251366971666744' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.425026858780175' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.023817516944188' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.305953795521837' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.405643407297801' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4357237073843323' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0937356475832176' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7242080639179056' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9303548186926622' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.324576633184378' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.234139690470583' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.068111280595808' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.28213077564420536' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1465614608846624' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.146879203680786' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6878003230970429' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7517584895388373' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.550915956500131' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7698335023213433' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.629349880712541' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.473536573748693' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7780475233499942' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.573386929649276' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2417628705790167' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6517051656632813' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8811578303822163' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.1386185150454886' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0614615440959085' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6635905227523289' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.22196676971832' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5674198455609636' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2144392292213193' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.348876156185362' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.374829167235278' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1287249435070335' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9383556601521742' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.10434593988946665' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# ...
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.022409014164774' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.10898535531989' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.601173944657242' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.995336063058354' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.004168226684419455' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.73135198839109' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4206114165772266' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.255761155711575' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.144331361848517' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4367382959008896' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.17628328516804' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1176743626375005' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.782244571376676' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.6060173986892976' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.0465287720817065' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.057903632813643455' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.07273436972831053' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.648954582259064' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2832648365827133' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.390217951377585' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.2414494724215962' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.173506771579438' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.617537636874213' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4632544167025692' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.807763744041326' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.642577951409998' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9018545409607307' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2471323609431573' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5797331595870816' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9537267344728828' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.792088684992603' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.20958227128773' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.99454855242442' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.9357066062366743' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.010954460087785' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.210033054731703' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.32665462387007' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '52.85602222421' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30.423841882813043' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.69577578035629' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '29.967819558686788' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.568072352456436' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.785675634499093' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1520128957364413' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7928416104296001' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.34239227295869307' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8472673830108539' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# /tmp/ipython-input-757050905.py:180: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.04655514509525515' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[idx, col] = submit_dict.get((date, col), 0)
# 제출 파일 저장 완료: lgbm_optuna_ensemble_submission.csv

# %% [markdown]
# 좋아요, 그럼 지금까지 당신 코드에 적용한 모든 변경 사항을 단계별로 정리해 드릴게요.
# 원본은 LSTM 베이스라인이었는데, 지금은 **전역 LightGBM + Optuna 튜닝 + 피처 엔지니어링 + 앙상블 + 제출 포맷 수정** 구조로 완전히 변했습니다.
#
# ---
#
# ## 1. **모델 구조 변경**
#
# * **기존**: 업장×메뉴별 개별 LSTM, 시계열만 입력, horizon=7 멀티 아웃풋
# * **변경**: 전 업장·메뉴 데이터를 합쳐서 전역(Global) LightGBM 모델로 학습
#
#   * Horizon=1\~7 각각 별도 모델 → Direct Multi-Horizon 방식
#   * `담하`, `미라시아` 업장은 샘플 가중치 3배 적용 (리더보드 유리)
#
# ---
#
# ## 2. **데이터 로드 & 컬럼 분리**
#
# * `train.csv`, `sample_submission.csv`, `TEST_*.csv` 모두 로드
# * **LSTM 포맷 호환을 위해**:
#
#   ```python
#   if '영업장명' not in train.columns:
#       train[['영업장명','메뉴명']] = train['영업장명_메뉴명'].str.split('_', n=1, expand=True)
#   if '영업장명' not in test_all.columns:
#       test_all[['영업장명','메뉴명']] = test_all['영업장명_메뉴명'].str.split('_', n=1, expand=True)
#   ```
#
#   → 업장명/메뉴명 분리해 groupby와 가중치 계산 가능하게 함.
#
# ---
#
# ## 3. **피처 엔지니어링**
#
# ### (1) 날짜 기반 특징 (`create_features`)
#
# * `year`, `month`, `day`, `dayofweek`, `weekofyear`, `is_weekend`
# * **공휴일 플래그**: `holidays.KR` 라이브러리로 연도별 공휴일 생성
# * **성수기 플래그**: 7,8,12,1월 → 1
#
# ### (2) Lag & Rolling (`add_lag_features`)
#
# * Lag: 1, 2, 3, 7, 14일 전 매출
# * Rolling Mean & Std: 최근 7, 14일 평균·표준편차
#
# ### (3) 카테고리 인코딩
#
# * LightGBM 입력 시 `영업장명`, `메뉴명`, `영업장명_메뉴명`을 `.astype('category')`
#
# ---
#
# ## 4. **Optuna 하이퍼파라미터 튜닝**
#
# * Horizon=1 모델만 대상으로 Optuna 실행 (30 trials)
# * 탐색 파라미터:
#
#   * `learning_rate`
#   * `num_leaves`
#   * `feature_fraction`
#   * `bagging_fraction`
#   * `bagging_freq`
#   * `lambda_l1`
#   * `lambda_l2`
# * 최적 파라미터를 나머지 Horizon에도 동일 적용
#
# ---
#
# ## 5. **Multi-Horizon 학습**
#
# * day+1 \~ day+7 각각 별도의 LightGBM 회귀 모델 학습
# * 각 모델에 업장 가중치 반영
#
# ---
#
# ## 6. **예측 및 앙상블**
#
# * LightGBM 예측 + Seasonal Naive(lag\_7) + 이동평균(roll\_mean\_7)
# * 가중치:
#
#   * LightGBM: 0.6
#   * Seasonal Naive: 0.2
#   * Moving Average: 0.2
# * `np.clip(..., 0, None)`로 음수 예측값 0으로 보정
#
# ---
#
# ## 7. **제출 포맷 변환 (0 나오는 문제 해결)**
#
# * **기존 문제**: `submit_dict` 키가 `(업장명, 메뉴명)` tuple인데, `sample_submission`의 컬럼은 `'업장명_메뉴명'` 문자열 → 매칭 실패 → 전부 0
# * **수정**:
#
#   ```python
#   menu_str = f"{row['영업장명']}_{row['메뉴명']}"
#   key = (f"{row['test_prefix']}+{day_ahead}일", menu_str)
#   ```
#
#   → `submit_dict` 키와 `sample_submission` 컬럼명을 동일한 문자열 형식으로 통일
# * 이렇게 해서 예측값이 정상적으로 들어가도록 수정
#
# ---
#
# ## 8. **기타 개선**
#
# * `FutureWarning`는 남아 있지만 동작에는 영향 없음 (원하면 dtype 명시로 제거 가능)
# * 전체 파이프라인이 **train → Optuna → 7모델 학습 → test 예측 → 제출 변환**까지 한 번에 실행되도록 구성
#
# ---
#
# 정리하면, 지금 돌리고 있는 건:
#
# > **전역 LightGBM + 풍부한 피처 + 가중치 적용 + Optuna 튜닝 + 앙상블 + 제출 포맷 수정**
# > LSTM 대비 데이터 효율성과 예측 안정성이 크게 향상된 구조
#
# ---
#
# 원하면 제가 여기서 **FutureWarning 제거**까지 해서 깔끔한 최종본 코드로 만들어 드릴 수 있어요.
# 그렇게 하면 경고 없이 실행되고, 결과도 동일하게 나옵니다.
# 그걸 해드릴까요?

# %% [markdown]
# ## EDA
